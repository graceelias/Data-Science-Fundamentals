# %% [markdown]
# # Worksheet 18
#
# Name:  Grace Elias
# UID: U91459237
#
# ### Topics
#
# - Linear Regression
#
# ### Optional Challenge
#
# Every day my alarm goes off at seemingly random times… I’ve recorded the times at which it goes off for the past year of so (1 - 355 days). Today is day 356. Can you predict when my alarm will ring using `data.csv`?
#
# Please fill out the piazza poll if you think you found the answer.
#
# ## Linear Regression
#
# Where does randomness come from?

# %%
pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython<9 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (7.31.1)
# Requirement already satisfied: numpy in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (1.21.2)
# Requirement already satisfied: ipython-genutils in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (8.4.0)
# Requirement already satisfied: traitlets<6 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (3.5.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: decorator in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (5.1.0)
# Requirement already satisfied: pickleshare in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: pygments in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (2.10.0)
# Requirement already satisfied: backcall in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: appnope in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.19.2)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: cycler>=0.10 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.31.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/graceelias/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.2.1)
# Requirement already satisfied: nest-asyncio in /Users/graceelias/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.4)
# Requirement already satisfied: psutil in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.8.0)
# Requirement already satisfied: pyzmq>=17 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/graceelias/.local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.6)
# Requirement already satisfied: attrs>=17.4.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.0)
# Requirement already satisfied: entrypoints in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.3)
# Requirement already satisfied: jinja2 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.2)
# Requirement already satisfied: argon2-cffi in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.12.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: bleach in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.4.3)
# Requirement already satisfied: testpath in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.0)
# Requirement already satisfied: defusedxml in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.3)
# Requirement already satisfied: pycparser in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Requirement already satisfied: async-generator in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.10)
# Requirement already satisfied: webencodings in /Users/graceelias/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 6.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

SAMPLE_SIZE = 100

# it's possible for y = 3 * x_1 + (1/4) * x_2
# but we don't know to look for x_2 and we only have x_1 as a feature
x1 = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
x2 = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = 3 * x1 + (1/4) * x2

# Create the figure
fig = plt.figure()

# Add an axes
ax = fig.add_subplot(111,projection='3d')

# and plot the point 
ax.scatter(x1 , x2 , y,  color='green')
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("y")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# a) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 0.5 * X + eps`.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

fig = plt.figure()

ax = fig.subplots()

true_beta = np.array([1,.5])
x_plot = np.linspace(-10,10,50)

x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = true_beta[0] + true_beta[1] * x + np.random.randn(SAMPLE_SIZE)

plt.plot(x,y,'ro',markersize=4)
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot, lw=2, c='g', label='Truth')

ax.set_xlim(-10,10)
ax.set_ylim(-10,10)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# b) Plot the least squares estimate line through the scatter plot.

# %%
fig = plt.figure()
ax = fig.subplots()
ax.set_xlim(-10,10)
ax.set_ylim(-10,10)

intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10,10,50)
y_est = beta_hat[0] + beta_hat[1] * x_plot
plt.plot(x_plot, y_est,'b--', lw=2, label='Estimate')
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot, lw=2, c='g', label='Truth')
plt.plot(x, y,'ro',markersize=4)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# c) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %% [markdown]
# It's fairly similar, the slope is slightly off but it represents the dataset fairly well.

# %% [markdown]
# d) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 3 * X + .5 * X^2 + eps`.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

fig = plt.figure()

ax = fig.subplots()

true_beta = np.array([1,3,.5])
x_plot = np.linspace(-10,10,50)

x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = true_beta[0] + true_beta[1]*x + true_beta[2]*x*x + np.random.randn(SAMPLE_SIZE)

plt.plot(x,y,'ro',markersize=4)
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot + true_beta[2]*x_plot*x_plot, lw=2, c='g', label='Truth')

ax.set_xlim(-10,10)
ax.set_ylim(-10,10)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# e) Plot the least squares estimate line through the scatter plot.

# %%
fig = plt.figure()
ax = fig.subplots()
ax.set_xlim(-10,10)
ax.set_ylim(-10,10)

intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x, x**2]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10,10,50)
y_est = beta_hat[0] + beta_hat[1] * x_plot + beta_hat[2]*x_plot*x_plot
plt.plot(x_plot, y_est,'b--', lw=2, label='Estimate')
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot + beta_hat[2]*x_plot*x_plot, lw=2, c='g', label='Truth')
plt.plot(x, y,'ro',markersize=4)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# f) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %% [markdown]
# It is pretty accurate.

# %% [markdown]
# g) Let's repeat d) and f) a large number of times to see how close our estimates are on average and what that distribution looks like.

# %%
import numpy as np
import matplotlib.pyplot as plt

# d
fig = plt.figure()

ax = fig.subplots()

betas = []
true_beta = np.array([ 1,  .5])
for _ in range(10000):
    x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
    y = true_beta[0] + true_beta[1] * x + np.random.randn(SAMPLE_SIZE)
    intercept = np.ones(np.shape(x)[0])
    X = np.array([intercept, x]).T
    betas.append(y)

plt.hist(np.array(betas)[:, 1], bins=100)
plt.axvline(x=true_beta[1], c='r', linestyle='dashed')
plt.show()

# f
fig = plt.figure()

ax = fig.subplots()

betas = []
true_beta = np.array([ 1, 3, .5])
for _ in range(10000):
    x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
    y = true_beta[0] + true_beta[1]*x + true_beta[2]*x*x + np.random.randn(SAMPLE_SIZE)
    intercept = np.ones(np.shape(x)[0])
    X = np.array([intercept, x, x**2]).T
    betas.append(y)

plt.hist(np.array(betas)[:, 1], bins=100)
plt.axvline(x=true_beta[1], c='r', linestyle='dashed')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
